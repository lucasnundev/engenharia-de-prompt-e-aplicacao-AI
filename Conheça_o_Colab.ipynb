# %% [markdown]
# <a href="https://colab.research.google.com/github/lucasnundev/engenharia-de-prompt-e-aplicacao-AI/blob/main/Conhe%C3%A7a_o_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Aula 7 de miniprojeto

# %%
print ("olá turma de quarta-feira")
# Out:
# olá turma de quarta-feira

# %%
#SOMA DE LISTA
numeros = [1,1,1,1,1] # Exemplo de lista
soma = sum(numeros)
print(soma)
# Out:
# 5

# %%
import math

#Numero primo
def eh_primo(n):
  if n < 2:
    return False
  if n == 2:
    return True
  if n % 2 == 0: # Otimização: Elimina números pares maiores que 2
    return False
  # Verifica divisores ímpares a partir de 3 até a raiz quadrada de n
  for i in range(3, int(n**0.5) + 1, 2):
    if n % i == 0:
      return False
  return True

# %%
print(f'7 é primo? {eh_primo(7)}') # Esperado: True
print(f'10 é primo? {eh_primo(10)}') # Esperado: False
print(f'2 é primo? {eh_primo(2)}')   # Esperado: True
print(f'1 é primo? {eh_primo(1)}')   # Esperado: False
print(f'11 é primo? {eh_primo(11)}') # Esperado: True
print(f'97 é primo? {eh_primo(97)}') # Esperado: True (exemplo de número maior)

# %%
def adicionar(a, b):
  return a + b

def subtrair(a, b):
  return a - b

def multiplicar(a, b):
  return a * b

def dividir(a, b):
  if b == 0:
    raise ValueError("Erro: Divisão por zero não é permitida!")
  return a / b
print(f"5 + 3 = {adicionar(5, 3)}")
print(f"10 - 4 = {subtrair(10, 4)}")
print(f"6 * 7 = {multiplicar(6, 7)}")
print(f"20 / 5 = {dividir(20, 5)}")

# Teste de divisão por zero
try:
  print(f"10 / 0 = {dividir(10, 0)}")
except ValueError as e:
  print(e)
# Out:
# 5 + 3 = 8
# 10 - 4 = 6
# 6 * 7 = 42
# 20 / 5 = 4.0
# Erro: Divisão por zero não é permitida!
